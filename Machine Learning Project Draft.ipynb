# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import json

# Enter your keys/secrets as strings in the following fields
# keys are securely stored on computer elsewhere
# not available on Github for security
credentials = {}
credentials['CONSUMER_KEY'] = '###'
credentials['CONSUMER_SECRET'] = '###'
credentials['ACCESS_TOKENKEY'] = '###'
credentials['ACCESS_SECRET'] = '###'

# Save the credentials object to file
with open("twitter_credentials.json", "w") as file:
    json.dump(credentials, file)

# %%
# Import the Twython class
from twython import Twython
import json

# Load credentials from json file
with open("twitter_credentials.json", "r") as file:
    creds = json.load(file)

# Instantiate an object
python_tweets = Twython(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])

# Create our query
query = {'q': '#DezNat',
        'result_type': 'recent',
        'lang': 'en',
         'count': 1000000
        }

# %%
import pandas as pd

# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': []}
for status in python_tweets.search(**query)['statuses']:
    dict_['user'].append(status['user']['screen_name'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['favorite_count'].append(status['favorite_count'])

# Structure data in a pandas DataFrame for easier manipulation
df = pd.DataFrame(dict_)
df.sort_values(by='favorite_count', inplace=True, ascending=False)
df
# Out:
#                user                            date  \
# 98     TheTrueAggie  Mon Dec 02 19:37:02 +0000 2019
# 49     JReubenCIark  Tue Dec 03 09:22:54 +0000 2019
# 22     Matthew_7_14  Tue Dec 03 17:42:56 +0000 2019
# 60         JPBellum  Tue Dec 03 05:14:13 +0000 2019
# 7          JPBellum  Tue Dec 03 21:42:41 +0000 2019
# 92       TheDMT1232  Mon Dec 02 20:31:08 +0000 2019
# 36  LatterdayDoofus  Tue Dec 03 13:14:20 +0000 2019
# 48     JReubenCIark  Tue Dec 03 09:30:39 +0000 2019
# 28         JPBellum  Tue Dec 03 15:50:45 +0000 2019
# 96       DrexelGuzy  Mon Dec 02 19:39:51 +0000 2019
# 85       Build_Zion  Mon Dec 02 21:34:34 +0000 2019
# 63   SiblingsinZion  Tue Dec 03 03:50:06 +0000 2019
# 83       TheDMT1232  Mon Dec 02 22:05:04 +0000 2019
# 43    ApostolicKeys  Tue Dec 03 10:51:08 +0000 2019
# 23       Mormonius2  Tue Dec 03 17:26:37 +0000 2019
# 18   DezNatDmgCntrl  Tue Dec 03 18:32:56 +0000 2019
# 59        Luv2GoFly  Tue Dec 03 05:20:24 +0000 2019
# ...

# %%
import csv
df.to_csv('tweets.csv')

# %%
# command line prompt: 
# twurl "/1.1/search/tweets.json?q=#deznat&result_type=popular"

# %%
from twython import TwythonStreamer
import csv

# Filter out unwanted data
def process_tweet(tweet):
    d = {}
    d['hashtags'] = [hashtag['text'] for hashtag in tweet['entities']['hashtags']]
    d['text'] = tweet['text']
    d['user'] = tweet['user']['screen_name']
    d['user_loc'] = tweet['user']['location']
    return d
    
    
# Create a class that inherits TwythonStreamer
class MyStreamer(TwythonStreamer):     

    # Received data
    def on_success(self, data):

        # Only collect tweets in English
        if data['lang'] == 'en':
            tweet_data = process_tweet(data)
            self.save_to_csv(tweet_data)

    # Problem with the API
    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()
        
    # Save each tweet to csv file
    def save_to_csv(self, tweet):
        with open(r'saved_tweets.csv', 'a') as file:
            writer = csv.writer(file)
            writer.writerow(list(tweet.values()))

# %%
# Instantiate from our streaming class
stream = MyStreamer(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'], 
                    creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])
# Start the stream
stream.statuses.filter(track='#deznat')

# %%
# Out:
# {'CONSUMER_KEY': 'QlMfjU2XMEkWTTYdpVXddsrh4', 'CONSUMER_SECRET': 'd0yLyvO3d9M5Kum9RxEj2Le08i7hOTjpaEo5YuAPhj2Y2WgOqe', 'ACCESS_TOKEN': '738920963836780544-ZK2NIZcKtacuVah5UYk81XZdYUQBoD6', 'ACCESS_SECRET': 'gLCyFSDzyFPZNBBOeQ4uuEpsizMpUQszZ101jHb60MTJm'}

# %%
import tweepy

auth = tweepy.auth.OAuthHandler(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])
auth.set_access_token(creds['ACCESS_TOKENKEY'], creds['ACCESS_SECRET'])
api = tweepy.API(auth)
search_results = api.search(q="#deznat")

# %%
print(search_results)
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000017A17C65B70>, _json={'created_at': 'Tue Dec 03 22:59:24 +0000 2019', 'id': 1201999402841333761, 'id_str': '1201999402841333761', 'text': 'RT @Matthew_7_14: Got the text from #LightTheWorld to go donate blood, so I took an early lunch.\n\n#DezNat https://t.co/At7JOpwuV1', 'truncated': False, 'entities': {'hashtags': [{'text': 'LightTheWorld', 'indices': [36, 50]}, {'text': 'DezNat', 'indices': [98, 105]}], 'symbols': [], 'user_mentions': [{'screen_name': 'Matthew_7_14', 'name': 'Matt', 'id': 1442170544, 'id_str': '1442170544', 'indices': [3, 16]}], 'urls': [], 'media': [{'id': 1201919753058705408, 'id_str': '1201919753058705408', 'indices': [106, 129], 'media_url': 'http://pbs.twimg.com/media/EK4TpbmW4AAeFKU.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EK4TpbmW4AAeFKU.jpg', 'url': 'https://t.co/At7JOpwuV1', 'display_url': 'pic.twitter.com/At7JOpwuV1', 'expanded_url': 'https://twitter.com/Matthew_7_14/status/1201919760444866560/pho
# ...

# %%
data = json.dumps(search_results)
tweets = json.loads(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-1a0924ccfa9d> in <module>
# ----> 1 data = json.dumps(search_results)
#       2 tweets = json.loads(data)
#
# C:\Programs\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# C:\Programs\lib\json\encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
# ...
